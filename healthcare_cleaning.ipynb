# %% [markdown]
# # Healthcare Data Cleaning

# %%
import pandas as pd

# %%
data = {
    'Patient_ID':[1,2,3,4,5],
    'Age':[25, None, 37, 29, None],
    'Gender':['F','M','F','F','M'],
    'Visit_Cost':[2000,3000,2500,None,4000]
}

# %%
df = pd.DataFrame(data)
df = df.fillna(method='ffill')
df
